# %% [markdown]
# # Projeto 2

# %% [markdown]
# ***

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
# Carrega o dataset
df_dsa = pd.read_csv('arquivos/dataset.csv')

# %%
# Shape
df_dsa.shape
# Out:
# (9700, 11)

# %%
# Amostra dos dados pelo início
df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %%
# Amostra dos dados pelo fim
df_dsa.tail()
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 9695  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9696  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9697  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9698  CA-2017-105291  30/10/2017   SP-20920     Consumer  United States
# 9699  CA-2018-147032  31/07/2018   LB-16795  Home Office  United States
#
#                Cidade      Estado       ID_Produto        Categoria  \
# 9695        Inglewood  California  OFF-PA-10004569  Office Supplies
# 9696        Inglewood  California  OFF-AP-10000027  Office Supplies
# 9697        Inglewood  California  TEC-PH-10000675       Technology
# 9698  San Luis Obispo  California  OFF-FA-10003059  Office Supplies
# 9699       Wilmington    Delaware  OFF-PA-10003256  Office Supplies
#
#      SubCategoria  Valor_Venda
# 9695        Paper       22.830
# 9696   Appliances       54.320
# ...

# %%
# Colunas do conjunto de dados
df_dsa.columns
# Out:
# Index(['ID_Pedido', 'Data_Pedido', 'ID_Cliente', 'Segmento', 'Pais', 'Cidade',
#        'Estado', 'ID_Produto', 'Categoria', 'SubCategoria', 'Valor_Venda'],
#       dtype='object')

# %%
# Verificando o tipo de dado de cada coluna
df_dsa.dtypes
# Out:
# ID_Pedido        object
# Data_Pedido      object
# ID_Cliente       object
# Segmento         object
# Pais             object
# Cidade           object
# Estado           object
# ID_Produto       object
# Categoria        object
# SubCategoria     object
# Valor_Venda     float64
# dtype: object

# %%
# Resumo estatístico da coluna com o valor de venda
df_dsa['Valor_Venda'].describe()
# Out:
# count     9700.000000
# mean       230.469892
# std        627.504252
# min          0.444000
# 25%         17.248000
# 50%         54.272000
# 75%        209.932500
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %%
# Verificando se há registros duplicados
df_dsa[df_dsa.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID_Pedido, Data_Pedido, ID_Cliente, Segmento, Pais, Cidade, Estado, ID_Produto, Categoria, SubCategoria, Valor_Venda]
# Index: []

# %%
# Verificando de há valores ausentes
df_dsa.isnull().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Cidade          0
# Estado          0
# ID_Produto      0
# Categoria       0
# SubCategoria    0
# Valor_Venda     0
# dtype: int64

# %%
df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Pergunta de Negócio 1:</b> Qual cidade com maior valor de venda de produtos da categoria 'Office Supplies'?
# </div>

# %%
# Filtro do dataframe da cidade com maior valor de venda de produtos da categoria 'office supplies':
df_dsa_prdct = df_dsa[df_dsa['Categoria'] == 'Office Supplies']
print(df_dsa_prdct)
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 2     CA-2017-138688  12/06/2017   DV-13045    Corporate  United States
# 4     US-2016-108966  11/10/2016   SO-20335     Consumer  United States
# 6     CA-2015-115812  09/06/2015   BH-11710     Consumer  United States
# 8     CA-2015-115812  09/06/2015   BH-11710     Consumer  United States
# 9     CA-2015-115812  09/06/2015   BH-11710     Consumer  United States
# ...              ...         ...        ...          ...            ...
# 9693  CA-2015-144281  10/06/2015   HK-14890    Corporate  United States
# 9695  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9696  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9698  CA-2017-105291  30/10/2017   SP-20920     Consumer  United States
# 9699  CA-2018-147032  31/07/2018   LB-16795  Home Office  United States
#
#                Cidade      Estado       ID_Produto        Categoria  \
# ...

# %%
# Agrupamento (Group By)
df_dsa_prdct_total = df_dsa_prdct.groupby('Cidade')['Valor_Venda'].sum()
print(df_dsa_prdct_total)
# Out:
# Cidade
# Aberdeen         25.500
# Abilene           1.392
# Akron          1107.646
# Albuquerque     943.122
# Alexandria     4879.790
#                  ...
# Woonsocket      142.590
# Yonkers         665.964
# York            395.920
# Yucaipa          50.800
# Yuma             55.352
# Name: Valor_Venda, Length: 480, dtype: float64

# %%
# Encontrando a cidade com o maior valor de venda
highest_sales_city = df_dsa_prdct_total.idxmax()
print(f"A cidade que mais tem o maior valor de vendas para a categoria 'Office Supplies' é: {highest_sales_city}")
# Out:
# A cidade que mais tem o maior valor de vendas para a categoria 'Office Supplies' é: New York City

# %%
# Cidades em valor decrescente
df_dsa_prdct_total.sort_values(ascending=False)
# Out:
# Cidade
# New York City    68362.814
# Los Angeles      47098.100
# San Francisco    41771.198
# Seattle          34856.878
# Philadelphia     29313.687
#                    ...
# Ormond Beach         2.808
# Pensacola            2.214
# Jupiter              2.064
# Elyria               1.824
# Abilene              1.392
# Name: Valor_Venda, Length: 480, dtype: float64

# %% [markdown]
# ***

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Pergunta de Negócio 2:</b> Qual o total de vendas por data do pedido?
# <p>Demonstre o resultado através de um gráfico de barras.</p>
# </div>

# %%
# Calcular o valor total de vendas para cada data de pedido
df_dsa_prdct2 = df_dsa.groupby('Data_Pedido')['Valor_Venda'].sum()
print(df_dsa_prdct2) # df_dsa_prdct2.head()
# Out:
# Data_Pedido
# 01/01/2018    1481.8280
# 01/02/2015     468.9000
# 01/02/2017     161.9700
# 01/03/2015    2203.1510
# 01/03/2016    1642.1744
#                 ...
# 31/10/2017    2346.5790
# 31/10/2018     523.9280
# 31/12/2015    5253.2700
# 31/12/2016    1381.3440
# 31/12/2017     731.7680
# Name: Valor_Venda, Length: 1226, dtype: float64

# %%
# Plot

    # Configurando o tamanho da figura
plt.figure(figsize=(18,6))

    # Criando o gráfico
df_dsa_prdct2.plot(x='Data_Pedido', y='Valor_Venda', color='magenta')

    # Definindo o título
plt.title('Total de Vendas pela Data do Pedido')

    # Mostrando o gráfico
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Pergunta de Negócio 3:</b> Qual o total de vendas por estado?
# <p>Demonstre o resultado através de um gráfico de barras.</p>
# </div>

# %%
# Agrupando o valor total de vendas por Estado
df_dsa_prdct3 = df_dsa.groupby('Estado')['Valor_Venda'].sum().reset_index()
print(df_dsa_prdct2) # df_dsa_prdct2.head()
# Out:
# Data_Pedido
# 01/01/2018    1481.8280
# 01/02/2015     468.9000
# 01/02/2017     161.9700
# 01/03/2015    2203.1510
# 01/03/2016    1642.1744
#                 ...
# 31/10/2017    2346.5790
# 31/10/2018     523.9280
# 31/12/2015    5253.2700
# 31/12/2016    1381.3440
# 31/12/2017     731.7680
# Name: Valor_Venda, Length: 1226, dtype: float64

# %%
# Plot

    # Configurando o tamanho da figura
plt.figure(figsize=(18,6))

    # Criando o gráfico
sns.barplot(data = df_dsa_prdct3, 
            x='Estado', 
            y='Valor_Venda') \
                .set(title = 'Vendas por Estado')
    
    # Definindo a rotação
plt.xticks(rotation=70)

    # Mostrando o gráfico
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Pergunta de Negócio 4:</b> Quais são as 10 cidades com maior total de vendas?
# <p>Demonstre o resultado através de um gráfico de barras.</p>
# </div>

# %%
# Agrupamento das cidades, total de vendas e lista ordenada com as 10 primeiras cidades em vendas
df_dsa_prdct4 = df_dsa.groupby('Cidade')['Valor_Venda'].sum().reset_index().sort_values(by = 'Valor_Venda', ascending = False).head(10)
print(df_dsa_prdct4)
# Out:
#             Cidade  Valor_Venda
# 327  New York City  251749.2190
# 265    Los Angeles  171654.6330
# 450        Seattle  114725.4780
# 436  San Francisco  107489.9520
# 372   Philadelphia  107197.8030
# 207        Houston   61590.1868
# 435      San Diego   47458.3790
# 80         Chicago   46974.3430
# 216   Jacksonville   44713.1830
# 123        Detroit   42446.9440

# %%
# Plot gráfico

    # Configurando o tamanho da figura
plt.figure(figsize=(18,6))

    # Criando o gráfico
sns.barplot(data = df_dsa_prdct4, 
            x='Cidade', 
            y='Valor_Venda',
            palette='muted') \
                .set(title = 'As 10 Cidades com Maior Total de Vendas')
                
    # Mostrando o gráfico
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Pergunta de Negócio 5:</b> Qual segmento teve o maior total de vendas?
# <p>Demonstre o resultado através de um gráfico de pizza.</p>
# </div>

# %%
# Agrupado por 'Segmento' para obter o total de vendas a partir desta categoria
df_dsa_prdct5 = df_dsa.groupby('Segmento')['Valor_Venda'].sum().reset_index().sort_values(by = 'Valor_Venda', ascending = False)
print(df_dsa_prdct5)
# Out:
#       Segmento   Valor_Venda
# 0     Consumer  1.133834e+06
# 1    Corporate  6.792322e+05
# 2  Home Office  4.224914e+05

# %%
# É necessário converter os dados para obtenção deles em valores absolutos
def convert_to_absolute(values): 
    def my_format(pct): 
        total = sum(values) 
        val = int(round(pct * total / 100.0))
        return ' $ {v:d}'.format(v = val)
    return my_format
print(convert_to_absolute)
# Out:
# <function convert_to_absolute at 0x7f122b9e1820>

# %%
# Plot

# Tamanho da figura
plt.figure(figsize = (18, 6))

# Gráfico de pizza
plt.pie(df_dsa_prdct5['Valor_Venda'], 
        labels = df_dsa_prdct5['Segmento'],
        autopct = convert_to_absolute(df_dsa_prdct5['Valor_Venda']),
        startangle = 90)

# Limpa o círculo central
centre_circle = plt.Circle((0, 0), 0.82, fc = 'white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Labels e anotações
plt.annotate(text = 'Total de Vendas: ' + '$ ' + str(int(sum(df_dsa_prdct5['Valor_Venda']))), xy = (-0.25, 0))
plt.title('Total de Vendas Por Segmento')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Pergunta de Negócio 6:</b> Qual o total de vendas por segmento e por ano?
# </div>

# %%
# Ver colunas
df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %%
# Verificando o tipo da coluna 'Data_Pedido'
df_dsa.dtypes
# Out:
# ID_Pedido        object
# Data_Pedido      object
# ID_Cliente       object
# Segmento         object
# Pais             object
# Cidade           object
# Estado           object
# ID_Produto       object
# Categoria        object
# SubCategoria     object
# Valor_Venda     float64
# dtype: object

# %%
# Convertendo a coluna da data para o tipo datetime para trabalhar com o formato adequado
df_dsa['Data_Pedido'] = pd.to_datetime(df_dsa['Data_Pedido'], dayfirst = True)

# %%
# Extraindo o ano e criando nova coluna
df_dsa['Ano'] = df_dsa['Data_Pedido'].dt.year

# %%
df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano
# 0     261.9600  2017
# 1     731.9400  2017
# 2      14.6200  2017
# ...

# %%
# Total de vendas por categorias selecionadas pela pergunta
df_dsa_prdct6 = df_dsa.groupby(['Ano','Segmento'])['Valor_Venda'].sum()
print(df_dsa_prdct6)
# Out:
# Ano   Segmento
# 2015  Consumer       256719.9166
#       Corporate      125819.5957
#       Home Office     88229.0878
# 2016  Consumer       265295.2593
#       Corporate      114643.1229
#       Home Office     74134.1332
# 2017  Consumer       288459.5572
#       Corporate      203266.7398
#       Home Office    103639.6270
# 2018  Consumer       323359.6019
#       Corporate      235502.7284
#       Home Office    156488.5849
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Pergunta de Negócio 7:</b> Os  gestores  da  empresa  estão  considerando conceder  diferentes  faixas  de  descontos  e gostariam de fazer uma simulação com base na regra abaixo:
# </b>
# <p><p>Se o Valor_Venda for maior que 1000 recebe 15% de desconto.</p></p>
# <p>Se o Valor_Venda for menor que 1000 recebe 10% de desconto.</p>
# <p>Quantas vendas receberiam 15% de desconto?</p>
# </div>

# %%
# Criando uma coluna de acordo com a regra definida na questão
df_dsa['Desconto'] = np.where(df_dsa['Valor_Venda'] > 1000, 0.15, 0.1)

# %%
df_dsa.head(15)
# Out:
#          ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 0   CA-2017-152156  2017-11-08   CG-12520     Consumer  United States
# 1   CA-2017-152156  2017-11-08   CG-12520     Consumer  United States
# 2   CA-2017-138688  2017-06-12   DV-13045    Corporate  United States
# 3   US-2016-108966  2016-10-11   SO-20335     Consumer  United States
# 4   US-2016-108966  2016-10-11   SO-20335     Consumer  United States
# 5   CA-2015-115812  2015-06-09   BH-11710     Consumer  United States
# 6   CA-2015-115812  2015-06-09   BH-11710     Consumer  United States
# 7   CA-2015-115812  2015-06-09   BH-11710     Consumer  United States
# 8   CA-2015-115812  2015-06-09   BH-11710     Consumer  United States
# 9   CA-2015-115812  2015-06-09   BH-11710     Consumer  United States
# 10  CA-2015-115812  2015-06-09   BH-11710     Consumer  United States
# 11  CA-2015-115812  2015-06-09   BH-11710     Consumer  United States
# ...

# %%
# Mostra o total por cada valor da coluna 'Desconto'
df_dsa['Desconto'].value_counts()
# Out:
# 0.10    9243
# 0.15     457
# Name: Desconto, dtype: int64

# %%
print('As vendas totais com desconto de 15% seria o montante de 457.')
# Out:
# As vendas totais com desconto de 15% seria o montante de 457.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Pergunta de Negócio 8:</b> Considere  que  a  Empresa  decida  conceder  o  desconto  de  15%  do  item  anterior.  Qual seria a média do valor de venda antes e depois do desconto?
# </div>

# %%
# Criada coluna de cálculo do valor da venda menos o desconto
df_dsa['Valor_Venda_Desconto'] = df_dsa['Valor_Venda'] - (df_dsa['Valor_Venda'] * df_dsa['Desconto'])

# %%
df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano  Desconto  Valor_Venda_Desconto
# ...

# %%
# Filtro das vendas antes do desconto de 15%
df_dsa_prdct7_before_sale = df_dsa.loc[df_dsa['Desconto'] == 0.15, 'Valor_Venda']

# %%
df_dsa_prdct7_after_sale = df_dsa.loc[df_dsa['Desconto'] == 0.15, 'Valor_Venda_Desconto']

# %%
# Cálculo da média das vendas antes do desconto de 15%
avg_sales_before = df_dsa_prdct7_before_sale.mean()

# %%
# Cálculo da média das vendas depois do desconto de 15%
avg_sales_after = df_dsa_prdct7_after_sale.mean()

# %%
print('Média das vendas antes do desconto de 15%:', round(avg_sales_before, 2))
# Out:
# Média das vendas antes do desconto de 15%: 2116.81

# %%
print('Média das vendas depois do desconto de 15%:', round(avg_sales_after, 2))
# Out:
# Média das vendas depois do desconto de 15%: 1799.29

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Pergunta de Negócio 9:</b> Qual a média de vendas por segmento, por ano e por mês?
# <p>Demonstre o resultado através de gráfico de linha.</p>
# </div>

# %%
# Extração da coluna mês e gravação em nova variável
df_dsa['Mes'] = df_dsa['Data_Pedido'].dt.month

# %%
df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano  Desconto  Valor_Venda_Desconto  Mes
# ...

# %%
# Agrupamento por ano, mês e segmento e cálculo estatístico de agregação
df_dsa_prdct8 = df_dsa.groupby(['Ano', 'Mes', 'Segmento'])['Valor_Venda'].agg([np.sum, np.mean, np.median])

# %%
df_dsa_prdct8
# Out:
#                              sum        mean  median
# Ano  Mes Segmento
# 2015 1   Consumer      6896.6290  146.736787  36.440
#          Corporate     1701.5280  130.886769  51.940
#          Home Office   5607.5500  329.855882  62.820
#      2   Consumer      3167.8540  117.327926  22.776
#          Corporate      623.1180   69.235333  62.310
# ...                          ...         ...     ...
# 2018 11  Corporate    44357.9862  341.215278  79.530
#          Home Office  24009.3840  247.519423  56.560
#      12  Consumer     48107.4558  183.616244  52.533
#          Corporate    20524.4320  153.167403  46.460
#          Home Office  13022.3910  224.523983  49.260
#
# [144 rows x 3 columns]

# %%
# Extração dos níveis
yr = df_dsa_prdct8.index.get_level_values(0)
mnth = df_dsa_prdct8.index.get_level_values(1)
sgmnts = df_dsa_prdct8.index.get_level_values(2)

# %%
# Plot

plt.figure(figsize = (10,6))
sns.set()
fig1 = sns.relplot(kind = 'line',
                   data = df_dsa_prdct8,
                   y = 'mean',
                   x = mnth,
                   hue = sgmnts,
                   col = yr,
                   col_wrap = 4)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Pergunta de Negócio 10:</b> Qual o total de vendas por categoria e subcategoria, considerando somente as top 12 subcategorias?
# <p>Demonstre tudo através de um único gráfico.</p>
# </div>

# %%
df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano  Desconto  Valor_Venda_Desconto  Mes
# ...

# %%
# Agrupamento e soma
df_dsa_prdctfinal = df_dsa.groupby(['Categoria',
                             'SubCategoria']).sum(numeric_only = True).sort_values('Valor_Venda',
                                                                                   ascending = False).head(12)

# %%
# Conversão da coluna Valor_Venda em número int e classificação por categoria
df_dsa_prdctfinal = df_dsa_prdctfinal[['Valor_Venda']].astype(int).sort_values(by = 'Categoria').reset_index()

# %%
df_dsa_prdctfinal
# Out:
#           Categoria SubCategoria  Valor_Venda
# 0         Furniture       Chairs       317919
# 1         Furniture       Tables       202083
# 2         Furniture    Bookcases       108045
# 3         Furniture  Furnishings        88862
# 4   Office Supplies      Storage       216188
# 5   Office Supplies      Binders       194723
# 6   Office Supplies   Appliances       104061
# 7   Office Supplies        Paper        76312
# 8        Technology       Phones       325271
# 9        Technology     Machines       189238
# 10       Technology  Accessories       162791
# 11       Technology      Copiers       146248

# %%
# Criando outro dataframe com totais por categoria
df_dsa_prdctfinal_cat = df_dsa_prdctfinal.groupby('Categoria').sum(numeric_only = True).reset_index()

# %%
df_dsa_prdctfinal_cat
# Out:
#          Categoria  Valor_Venda
# 0        Furniture       716909
# 1  Office Supplies       591284
# 2       Technology       823548

# %%
# Listas de cores para categorias: #845EC2, #F3C5FF, #00C9A7
color_ctg = ['#845EC2',
                    '#F3C5FF',
                    '#00C9A7']

# %%
# Listas de cores para subcategorias

color_subctg = ['#6B4A9A',
                       '#A07BCB',
                       '#523D7E',
                       '#8D6FAF', #
                       '#DAA9E6',
                       '#F8D9FF',
                       '#CBA0E0',
                       '#E6BFEF', #
                       '#00997F',
                       '#00E3C0',
                       '#008A6E',
                       '#00B58F']

# %%
# Plot

# Tamanho da figura
fig, ax = plt.subplots(figsize = (18,12))

# Gráfico das categorias
p1 = ax.pie(df_dsa_prdctfinal_cat['Valor_Venda'], 
            radius = 1,
            labels = df_dsa_prdctfinal_cat['Categoria'],
            wedgeprops = dict(edgecolor = 'white'),
            colors = color_ctg)

# Gráfico das subcategorias
p2 = ax.pie(df_dsa_prdctfinal['Valor_Venda'],
            radius = 0.9,
            labels = df_dsa_prdctfinal['SubCategoria'],
            autopct = convert_to_absolute(df_dsa_prdctfinal['Valor_Venda']),
            colors = color_subctg, 
            labeldistance = 0.7,
            wedgeprops = dict(edgecolor = 'white'), 
            pctdistance = 0.53,
            rotatelabels = True)

# Limpa o centro do círculo
centre_circle = plt.Circle((0, 0), 0.6, fc = 'white')

# Labels e anotações
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.annotate(text = 'Total de Vendas: ' + '$ ' + str(int(sum(df_dsa_prdctfinal['Valor_Venda']))), xy = (-0.2, 0))
plt.title('Total de Vendas Por Categoria e Top 12 SubCategorias')
plt.show()
